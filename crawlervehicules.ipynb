# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# URL de base pour la catégorie Maison
BASE_URL = "https://www.expat-dakar.com/maison"

# Headers pour simuler un navigateur
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Fonction pour récupérer les liens des annonces sur une page donnée
def get_announcement_links(base_url, page):
    response = requests.get(f"{base_url}?page={page}", headers=HEADERS)
    soup = BeautifulSoup(response.text, "html.parser")
    
    # Extraire tous les liens des annonces
    links = []
    for item in soup.find_all("div", class_="listings-cards__list-item"):
        link_tag = item.find("a", href=True)
        if link_tag:
            href = link_tag['href']
            # Vérifiez que le lien est bien formaté
            if href.startswith("/"):  # Lien relatif
                links.append("https://www.expat-dakar.com" + href)
            elif href.startswith("http"):  # Lien absolu déjà formé
                links.append(href)
    
    return links

# Fonction pour récupérer les détails d'une annonce
def get_announcement_details(url):
    response = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(response.text, "html.parser")
    
    # Récupérer les informations spécifiques
    details = {}
    try:
        # Titre et prix
        details["Titre"] = soup.find("h1", class_="listing-item__header").text.strip() if soup.find("h1", class_="listing-item__header") else "N/A"
        details["Prix"] = soup.find("span", class_="listing-card__price__value").text.strip() if soup.find("span", class_="listing-card__price__value") else "N/A"
        
        # Adresse
        location = soup.find("span", class_="listing-item__address-location")
        region = soup.find("span", class_="listing-item__address-region")
        details["Adresse"] = f"{location.text.strip()} {region.text.strip()}" if location and region else "N/A"
        
        # Récupérer les détails listés dans "Détails"
        for dt, dd in zip(
            soup.find_all("dt", class_="listing-item__properties__title"),
            soup.find_all("dd", class_="listing-item__properties__description")
        ):
            details[dt.text.strip()] = dd.text.strip()
        
        # Description
        details["Description"] = soup.find("div", class_="listing-item__description").text.strip() if soup.find("div", class_="listing-item__description") else "N/A"
    except Exception as e:
        print(f"Erreur lors de l'extraction de {url}: {e}")
    
    return details

# Récupérer tous les liens et les détails des annonces sur plusieurs pages
print("Début du scraping des annonces de la catégorie Maison...")
all_links = []
data = []  # Pour stocker les détails des annonces

# Boucle pour parcourir les pages 
MAX_PAGES = 5  
for page in range(1, MAX_PAGES + 1):
    print(f"Scraping de la page {page}...")
    links = get_announcement_links(BASE_URL, page)
    all_links.extend(links)
    print(f"{len(links)} liens trouvés sur la page {page}.")
    
    # Récupérer les détails pour chaque annonce de cette page
    for link in links:
        print(f"Scraping des détails pour : {link}")
        details = get_announcement_details(link)
        data.append(details)
        time.sleep(1)  # Pause pour éviter de surcharger le serveur

# Sauvegarder les résultats dans un fichier Excel
df = pd.DataFrame(data)
df.to_excel("annonces_maison_expat_dakar.xlsx", index=False)
print("Les données ont été sauvegardées dans 'annonces_maison_expat_dakar.xlsx'.")
# Out:
# Début du scraping des annonces de la catégorie Maison...
# Scraping de la page 1...
# 11 liens trouvés sur la page 1.
# Scraping des détails pour : https://www.expat-dakar.com/annonce/cuisiniere-6088205
# Scraping des détails pour : https://www.expat-dakar.com/annonce/detergent-tide-pods-3-en-1-6241110
# Scraping des détails pour : https://www.expat-dakar.com/annonce/salon-de-6-place-en-simili-cuir-england-bon-prix-6241106
# Scraping des détails pour : https://www.expat-dakar.com/annonce/cinq-lampes-solaires-de-jardin-15-lumens-sur-piquet-6241103
# Scraping des détails pour : https://www.expat-dakar.com/annonce/glaciere-igloo-10litres-2jours-de-conservation-6241093
# Scraping des détails pour : https://www.expat-dakar.com/annonce/salon-7-place-6241089
# Scraping des détails pour : https://www.expat-dakar.com/annonce/chaises-bureau-6241081
# Scraping des détails pour : https://www.expat-dakar.com/annonce/canapes-neuf-6241056
# Scraping des détails pour : https://www.expat-dakar.com/annonce/refrigerateur-bosh-3-tiroirs-inox-6219837
# Scraping des détails pour : https://www.expat-dakar.com/annonce/salon-4-places-en-cuir-a-vendre-6241053
# Scraping des détails pour : https://www.expat-dakar.com/annonce/chambre-a-coucher-enfant-a-vendre-6231158
# Scraping de la page 2...
# 11 liens trouvés sur la page 2.
# Scraping des détails pour : https://www.expat-dakar.com/annonce/extracteur-de-jus-1000-watts-6228618
# Scraping des détails pour : https://www.expat-dakar.com/annonce/meubles-de-rangement-6241057
# Scraping des détails pour : https://www.expat-dakar.com/annonce/allume-charbon-electrique-bruleur-a-charbon-portable-5583541
# Scraping des détails pour : https://www.expat-dakar.com/annonce/armoire-3-portes-6241014
# Scraping des détails pour : https://www.expat-dakar.com/annonce/armoire-4-portes-6241012
# Scraping des détails pour : https://www.expat-dakar.com/annonce/salon-7-place-6241009
# Scraping des détails pour : https://www.expat-dakar.com/annonce/chambre-a-coucher-6241007
# Scraping des détails pour : https://www.expat-dakar.com/annonce/matelas-orthopediques-6240987
# Scraping des détails pour : https://www.expat-dakar.com/annonce/bouilloire-electrique-astech-17-litres-6240977
# Scraping des détails pour : https://www.expat-dakar.com/annonce/machine-a-cafe-nespresso-vertu-gris-6240966
# Scraping des détails pour : https://www.expat-dakar.com/annonce/cuisiniere-astech-6-feux-6173517
# Scraping de la page 3...
# 11 liens trouvés sur la page 3.
# Scraping des détails pour : https://www.expat-dakar.com/annonce/buffet-a-vendre-6240579
# Scraping des détails pour : https://www.expat-dakar.com/annonce/bouilloire-electrique-6240958
# Scraping des détails pour : https://www.expat-dakar.com/annonce/housse-protection-matelas-6240957
# Scraping des détails pour : https://www.expat-dakar.com/annonce/canape-6-places-italienne-a-bon-etat-6240949
# Scraping des détails pour : https://www.expat-dakar.com/annonce/plaque-4feux-6060-encastrable-ceramique-hisense-6240946
# Scraping des détails pour : https://www.expat-dakar.com/annonce/chauffe-eau-astech-50l-6197605
# Scraping des détails pour : https://www.expat-dakar.com/annonce/machine-a-laver-hisense-7kg-a-6130706
# Scraping des détails pour : https://www.expat-dakar.com/annonce/canape-pliable-6240932
# Scraping des détails pour : https://www.expat-dakar.com/annonce/micro-ondes-20l-astech-6240934
# Scraping des détails pour : https://www.expat-dakar.com/annonce/lave-linge-sharp-t185x-8-kg-semi-automatique-6116335
# Scraping des détails pour : https://www.expat-dakar.com/annonce/refrigerateur-bar-roch-rfr-110dt-110-litres-2-portes-6222551
# Scraping de la page 4...
# 11 liens trouvés sur la page 4.
# Scraping des détails pour : https://www.expat-dakar.com/annonce/micro-ondes-four-exquisit-20-litres-6225676
# Scraping des détails pour : https://www.expat-dakar.com/annonce/canape-lit-gonflable-6240930
# Scraping des détails pour : https://www.expat-dakar.com/annonce/air-fryer-6240928
# Scraping des détails pour : https://www.expat-dakar.com/annonce/table-a-manger-5951667
# Scraping des détails pour : https://www.expat-dakar.com/annonce/table-a-manger-5867663
# Scraping des détails pour : https://www.expat-dakar.com/annonce/housse-matelas-impermeable-5654640
# Scraping des détails pour : https://www.expat-dakar.com/annonce/housse-de-protections-matelas-impermeable-en-coton-5828723
# Scraping des détails pour : https://www.expat-dakar.com/annonce/salon-moderne-rouge-6037582
# Scraping des détails pour : https://www.expat-dakar.com/annonce/table-tele-et-table-basse-6130520
# Scraping des détails pour : https://www.expat-dakar.com/annonce/salon-7-places-6230697
# Scraping des détails pour : https://www.expat-dakar.com/annonce/matelas-orthopedique-mt-confort-6184497
# Scraping de la page 5...
# 11 liens trouvés sur la page 5.
# Scraping des détails pour : https://www.expat-dakar.com/annonce/extracteur-de-jus-1000-watts-6228618
# Scraping des détails pour : https://www.expat-dakar.com/annonce/chambre-a-coucher-6222953
# Scraping des détails pour : https://www.expat-dakar.com/annonce/chambre-a-coucher-6-battants-6222962
# Scraping des détails pour : https://www.expat-dakar.com/annonce/lit-2-places-6206206
# Scraping des détails pour : https://www.expat-dakar.com/annonce/bibliotheque-6240857
# Scraping des détails pour : https://www.expat-dakar.com/annonce/des-tables-6240577
# Scraping des détails pour : https://www.expat-dakar.com/annonce/salons-en-cuir-tres-propres-neuf-6240829
# Scraping des détails pour : https://www.expat-dakar.com/annonce/canape-trop-confortable-6240850
# Scraping des détails pour : https://www.expat-dakar.com/annonce/split-6240866
# Scraping des détails pour : https://www.expat-dakar.com/annonce/airfryer-double-bac-michelino-2-fois-4-litres-2200watts-6225759
# Scraping des détails pour : https://www.expat-dakar.com/annonce/side-by-side-exquisit-600l-4-porte-a-6225685
# Les données ont été sauvegardées dans 'annonces_maison_expat_dakar.xlsx'.
